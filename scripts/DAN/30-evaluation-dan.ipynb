# %% [markdown]
# ## Evaluation DAN

# %% [markdown]
# Remarque : dans *nerval/parse.py* : les § ont été remplacés par |

# %%
# !teklia-dan evaluate --config /home/STual/configs/config3.json
# Out:
# ##################
# Available GPUS: 3
# Rank 0: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# Rank 1: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# Rank 2: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# ##################
# Local GPU:
# Rank 0: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# ##################
# Local GPU:
# Rank 1: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# ##################
# Local GPU:
# Rank 2: NVIDIA A40 _CudaDeviceProperties(name='NVIDIA A40', major=8, minor=6, total_memory=45466MB, multi_processor_count=84)
# ##################
# ...
