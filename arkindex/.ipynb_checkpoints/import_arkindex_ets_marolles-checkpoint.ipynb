# %% [markdown]
# # Import des images dans Arkindex
#
# - Création des éléments "Pages" dans Arkindex depuis le serveur IIIF
# - Les images au format paysage sont coupées en deux au préalable (doubles pages => page)
#
# [Voir le notebook sur Google Colab](https://colab.research.google.com/drive/1yPi5c902hu5imokr9vNiIs_HDPujf_aN?usp=sharing)

# %% [markdown]
# ## Pré-requis et documentation
#
# Documentation:
# - [Doc de l'API Arkindex](https://doc.arkindex.org/overview/api/)
# - [Doc du client Python de bas-niveau](https://pypi.org/project/arkindex-client/)
# - [Doc de Arkindex CLI (haut niveau)](https://cli.arkindex.org/)
#
# A installer :
# ```
# pip install arkindex-cli
# ```

# %% [markdown]
# ## Login

# %% [markdown]
# ### Prod instance

# %%
# !arkindex login --host arkindex.teklia.com --email solenn.tual@ign.fr

# %% [markdown]
# ## Import

# %%
import pandas
import os
import json
from arkindex import ArkindexClient

# %%
#Import des doubles pages
#!arkindex -p prod upload iiif-images /content/drive/MyDrive/THESE/Arkindex/ets_dataset_marolles_comp_iiif.txt --parent-folder 2a045b63-2866-4292-a168-87d342be800b --element-type page_marolles

# %% [markdown]
# ## Définition des métadonnées

# %%
cli = ArkindexClient('cdf9b285c9da6e82cddbf18aa070dc471a13facb')

# %%
#Retrieve corpus (project)
elements = cli.request('ListElementChildren',id="23719392-b55c-497e-bd29-3c3aded6fd44",type="page_marolles",recursive=True,folder=False,page_size=500,page=1)
print(elements["count"])
# Out:
# 29

# %%
elements
# Out:
# {'count': 29,
#  'number': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 'c8c9b171-906b-4ff9-8f43-dddc9905fc80',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0002',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'c8c9b171-906b-4ff9-8f43-dddc9905fc80',
#     'polygon': [[0, 0], [0, 4047], [2788, 4047], [2788, 0], [0, 0]],
#     'image': {'id': '883395dc-6c37-42f6-a7bf-d9b57bbd061b',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0002.jpg',
#      'width': 2788,
#      'height': 4047,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0002.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0002.jpg/0,0,2788,4047/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:04.859341Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'a0002f6b-d91e-49aa-980f-789bf1c89ba3',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0003',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'a0002f6b-d91e-49aa-980f-789bf1c89ba3',
#     'polygon': [[0, 0], [0, 4013], [2665, 4013], [2665, 0], [0, 0]],
#     'image': {'id': 'c4d1864d-5e5f-4258-bc06-8addd9464d72',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0003.jpg',
#      'width': 2665,
#      'height': 4013,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0003.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0003.jpg/0,0,2665,4013/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:06.236310Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '6d0f0e46-0e24-477f-95a2-495f79f6faef',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0006',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '6d0f0e46-0e24-477f-95a2-495f79f6faef',
#     'polygon': [[0, 0], [0, 4024], [2806, 4024], [2806, 0], [0, 0]],
#     'image': {'id': '163702dd-b2d0-479d-8f0b-4ca106e23de2',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0006.jpg',
#      'width': 2806,
#      'height': 4024,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0006.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0006.jpg/0,0,2806,4024/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:07.647688Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '51e0c722-c848-4dbb-8afe-327e49512258',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0007',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '51e0c722-c848-4dbb-8afe-327e49512258',
#     'polygon': [[0, 0], [0, 4027], [2609, 4027], [2609, 0], [0, 0]],
#     'image': {'id': 'b09a3d9e-6c0f-485f-8f8d-ae99b82a99d4',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0007.jpg',
#      'width': 2609,
#      'height': 4027,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0007.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0007.jpg/0,0,2609,4027/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:09.080746Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '6b7fc79d-6267-4a31-87d7-d70d692ed4bc',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0020',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '6b7fc79d-6267-4a31-87d7-d70d692ed4bc',
#     'polygon': [[0, 0], [0, 4077], [2769, 4077], [2769, 0], [0, 0]],
#     'image': {'id': '65214a2c-9f77-4c75-a245-4fa2331d5e45',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0020.jpg',
#      'width': 2769,
#      'height': 4077,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0020.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0020.jpg/0,0,2769,4077/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:10.437149Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '44cac607-e546-4b34-ac31-c8b8b0995ddb',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0021',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '44cac607-e546-4b34-ac31-c8b8b0995ddb',
#     'polygon': [[0, 0], [0, 4015], [2627, 4015], [2627, 0], [0, 0]],
#     'image': {'id': '6a0c6a45-9e2f-4189-84b2-c7776b6a42d9',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0021.jpg',
#      'width': 2627,
#      'height': 4015,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0021.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0021.jpg/0,0,2627,4015/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:11.817732Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '3e550d9c-f019-499a-9b30-da55245943e5',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0024',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '3e550d9c-f019-499a-9b30-da55245943e5',
#     'polygon': [[0, 0], [0, 4069], [2830, 4069], [2830, 0], [0, 0]],
#     'image': {'id': 'f1b79e2d-66f1-4f3d-9fea-5b0d29a548c9',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0024.jpg',
#      'width': 2830,
#      'height': 4069,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0024.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0024.jpg/0,0,2830,4069/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:13.282008Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '48decc78-e30f-4452-9835-124b51576da1',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0025',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '48decc78-e30f-4452-9835-124b51576da1',
#     'polygon': [[0, 0], [0, 4057], [2652, 4057], [2652, 0], [0, 0]],
#     'image': {'id': '91f2c564-b414-4b91-b7cb-60ee17397ac7',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0025.jpg',
#      'width': 2652,
#      'height': 4057,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0025.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0025.jpg/0,0,2652,4057/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:14.734366Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'bae6d53f-2370-41f4-9e34-0a310a5298b7',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0028',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'bae6d53f-2370-41f4-9e34-0a310a5298b7',
#     'polygon': [[0, 0], [0, 4071], [2830, 4071], [2830, 0], [0, 0]],
#     'image': {'id': '7b5381e7-36e1-4d1a-b93e-6265eb4ca183',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0028.jpg',
#      'width': 2830,
#      'height': 4071,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0028.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0028.jpg/0,0,2830,4071/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:16.101119Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'e29fa7ae-4c9c-4939-8641-a9dec141b26c',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0029',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'e29fa7ae-4c9c-4939-8641-a9dec141b26c',
#     'polygon': [[0, 0], [0, 4063], [2707, 4063], [2707, 0], [0, 0]],
#     'image': {'id': '74a44f22-1792-4d6d-8eb0-bd4b44ad5269',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0029.jpg',
#      'width': 2707,
#      'height': 4063,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0029.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0029.jpg/0,0,2707,4063/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:17.446150Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '3a902f11-c971-4377-ac79-65b8b9fae788',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0032',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '3a902f11-c971-4377-ac79-65b8b9fae788',
#     'polygon': [[0, 0], [0, 4071], [2818, 4071], [2818, 0], [0, 0]],
#     'image': {'id': '07e6e5cd-396c-4736-9f90-953a07d3c8a7',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0032.jpg',
#      'width': 2818,
#      'height': 4071,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0032.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0032.jpg/0,0,2818,4071/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:18.850502Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '026cec76-f3e4-4ad6-b914-e6043f9c39f5',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0041',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '026cec76-f3e4-4ad6-b914-e6043f9c39f5',
#     'polygon': [[0, 0], [0, 4093], [2843, 4093], [2843, 0], [0, 0]],
#     'image': {'id': '40074d6e-95fd-4c77-a9c0-b9884a101c1d',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0041.jpg',
#      'width': 2843,
#      'height': 4093,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0041.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0041.jpg/0,0,2843,4093/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:20.248731Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '340e53ca-85d4-459b-a1f2-31938fc811c7',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0042',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '340e53ca-85d4-459b-a1f2-31938fc811c7',
#     'polygon': [[0, 0], [0, 4007], [2609, 4007], [2609, 0], [0, 0]],
#     'image': {'id': '508a034a-0528-44e9-96c7-070ea3dd28c0',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0042.jpg',
#      'width': 2609,
#      'height': 4007,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0042.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0042.jpg/0,0,2609,4007/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:21.728644Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'c9346441-cf2f-4d0c-b88e-b858a883283b',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0045',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'c9346441-cf2f-4d0c-b88e-b858a883283b',
#     'polygon': [[0, 0], [0, 4113], [2837, 4113], [2837, 0], [0, 0]],
#     'image': {'id': 'a378536b-5d80-4353-8ba7-5dd6bcc0612e',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0045.jpg',
#      'width': 2837,
#      'height': 4113,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0045.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0045.jpg/0,0,2837,4113/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:23.053460Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '690d0a2e-7a2d-432d-9163-2eb96a1137c8',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0046',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '690d0a2e-7a2d-432d-9163-2eb96a1137c8',
#     'polygon': [[0, 0], [0, 4069], [2689, 4069], [2689, 0], [0, 0]],
#     'image': {'id': 'c393be42-9e4a-4d33-a4c9-4c8a175e6eb6',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0046.jpg',
#      'width': 2689,
#      'height': 4069,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0046.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0046.jpg/0,0,2689,4069/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:24.408114Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '8ad0f719-fd08-4b41-9329-42a5dc1fa3b9',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0049',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '8ad0f719-fd08-4b41-9329-42a5dc1fa3b9',
#     'polygon': [[0, 0], [0, 4113], [2824, 4113], [2824, 0], [0, 0]],
#     'image': {'id': '97e93156-cc76-47de-96ef-8fc1b8cf5f4f',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0049.jpg',
#      'width': 2824,
#      'height': 4113,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0049.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0049.jpg/0,0,2824,4113/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:25.815209Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '20311c8b-35ae-4696-80bf-995a261d64d2',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0054',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '20311c8b-35ae-4696-80bf-995a261d64d2',
#     'polygon': [[0, 0], [0, 4088], [2750, 4088], [2750, 0], [0, 0]],
#     'image': {'id': '76ccebb2-25f9-4653-a988-06912e59353f',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0054.jpg',
#      'width': 2750,
#      'height': 4088,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0054.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0054.jpg/0,0,2750,4088/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:27.157759Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'a563d0b8-0abb-4a1a-babf-890cab747321',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0057',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'a563d0b8-0abb-4a1a-babf-890cab747321',
#     'polygon': [[0, 0], [0, 4113], [2763, 4113], [2763, 0], [0, 0]],
#     'image': {'id': '9c4b13c8-5cf5-4f47-bdab-7a86c500799e',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0057.jpg',
#      'width': 2763,
#      'height': 4113,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0057.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0057.jpg/0,0,2763,4113/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:28.500263Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'ee8296b0-f328-4be0-a7d6-d98a3ee2f77d',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0076',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'ee8296b0-f328-4be0-a7d6-d98a3ee2f77d',
#     'polygon': [[0, 0], [0, 4113], [2769, 4113], [2769, 0], [0, 0]],
#     'image': {'id': '5f5fd47b-cc27-47cf-aef3-a045b1de4702',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0076.jpg',
#      'width': 2769,
#      'height': 4113,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0076.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0076.jpg/0,0,2769,4113/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:29.859721Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '2d56ef21-6f6d-4f8f-8af8-c2eebaf08b73',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0079',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '2d56ef21-6f6d-4f8f-8af8-c2eebaf08b73',
#     'polygon': [[0, 0], [0, 4107], [2763, 4107], [2763, 0], [0, 0]],
#     'image': {'id': '9db7f7cc-c26d-4200-8896-3f320dd39e69',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0079.jpg',
#      'width': 2763,
#      'height': 4107,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0079.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0079.jpg/0,0,2763,4107/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:31.217144Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '0ce77406-ae1c-4248-adc3-d4599ba702fb',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0080',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '0ce77406-ae1c-4248-adc3-d4599ba702fb',
#     'polygon': [[0, 0], [0, 4063], [2750, 4063], [2750, 0], [0, 0]],
#     'image': {'id': '56af7a41-db35-46c7-8f59-5a73c5f45c6f',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0080.jpg',
#      'width': 2750,
#      'height': 4063,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0080.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0080.jpg/0,0,2750,4063/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:32.576932Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '10d0200c-2d39-457b-9687-bd1ca6d38fb1',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0083',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '10d0200c-2d39-457b-9687-bd1ca6d38fb1',
#     'polygon': [[0, 0], [0, 4102], [2812, 4102], [2812, 0], [0, 0]],
#     'image': {'id': 'fb9d266b-2297-43fc-b1c1-fdfe7f0ece85',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0083.jpg',
#      'width': 2812,
#      'height': 4102,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0083.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0083.jpg/0,0,2812,4102/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:33.958614Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'bdf51b04-bcb8-469a-b8e2-03a380777f35',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0088',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'bdf51b04-bcb8-469a-b8e2-03a380777f35',
#     'polygon': [[0, 0], [0, 4088], [2770, 4088], [2770, 0], [0, 0]],
#     'image': {'id': '5460c6c4-a627-4521-8a02-8ef575befc28',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0088.jpg',
#      'width': 2770,
#      'height': 4088,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0088.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0088.jpg/0,0,2770,4088/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:35.377626Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '3fe40da1-daa7-42a9-b43b-cd1002827b8d',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0091',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '3fe40da1-daa7-42a9-b43b-cd1002827b8d',
#     'polygon': [[0, 0], [0, 4100], [2775, 4100], [2775, 0], [0, 0]],
#     'image': {'id': '997c9dea-e524-453c-bcb8-6bfb56746bc7',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0091.jpg',
#      'width': 2775,
#      'height': 4100,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0091.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0091.jpg/0,0,2775,4100/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:36.735817Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '2c7299da-97bb-4b08-9d81-8d714cdebc54',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0092',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '2c7299da-97bb-4b08-9d81-8d714cdebc54',
#     'polygon': [[0, 0], [0, 4082], [2776, 4082], [2776, 0], [0, 0]],
#     'image': {'id': '7fa8cea0-07c9-42e3-b0b2-814f0387bfa2',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0092.jpg',
#      'width': 2776,
#      'height': 4082,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0092.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0092.jpg/0,0,2776,4082/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:38.138563Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '204e0289-e4ea-4acd-9fbb-162d3cd896d5',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0095',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '204e0289-e4ea-4acd-9fbb-162d3cd896d5',
#     'polygon': [[0, 0], [0, 4088], [2751, 4088], [2751, 0], [0, 0]],
#     'image': {'id': 'ec118991-e77e-42aa-b884-6d8c75e29d31',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0095.jpg',
#      'width': 2751,
#      'height': 4088,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0095.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0095.jpg/0,0,2751,4088/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:39.519767Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '37491f3e-dc15-4467-922f-cf117dcbe15b',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0096',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '37491f3e-dc15-4467-922f-cf117dcbe15b',
#     'polygon': [[0, 0], [0, 4075], [2781, 4075], [2781, 0], [0, 0]],
#     'image': {'id': 'b7f020db-4a96-4b44-abf6-901e1fe70b84',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0096.jpg',
#      'width': 2781,
#      'height': 4075,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0096.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0096.jpg/0,0,2781,4075/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:40.888724Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': 'e483fe04-8259-44a7-9806-aca7a4e37508',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0099',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': 'e483fe04-8259-44a7-9806-aca7a4e37508',
#     'polygon': [[0, 0], [0, 4058], [2721, 4058], [2721, 0], [0, 0]],
#     'image': {'id': '41a8891b-55f2-4350-9deb-9235f550912a',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0099.jpg',
#      'width': 2721,
#      'height': 4058,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0099.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0099.jpg/0,0,2721,4058/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:42.239226Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None},
#   {'id': '2bce01a0-b075-4ca5-83cc-c61b256361d5',
#    'type': 'page_marolles',
#    'name': 'FRAD094_3P_000387_01_0100',
#    'corpus': {'id': '59285827-bba3-42d4-99c7-e2436fe19f94',
#     'name': 'EPITA-IGN | Registre Napoléonien',
#     'public': False},
#    'thumbnail_url': None,
#    'zone': {'id': '2bce01a0-b075-4ca5-83cc-c61b256361d5',
#     'polygon': [[0, 0], [0, 4082], [2787, 4082], [2787, 0], [0, 0]],
#     'image': {'id': '302729ca-34b8-429d-8d32-cf8da9995c98',
#      'path': 'CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0100.jpg',
#      'width': 2787,
#      'height': 4082,
#      'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0100.jpg',
#      's3_url': None,
#      'status': 'checked',
#      'server': {'display_name': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'url': 'https://iiif.geohistoricaldata.org/iiif/2',
#       'max_width': None,
#       'max_height': None}},
#     'url': 'https://iiif.geohistoricaldata.org/iiif/2/CADASTRE%2FETATS_DE_SECTION%2F%2FMAROLLES%2FFRAD094_3P_000387_01%2FFRAD094_3P_000387_01_0100.jpg/0,0,2787,4082/full/0/default.jpg'},
#    'rotation_angle': 0,
#    'mirrored': False,
#    'created': '2023-12-18T10:08:43.619546Z',
#    'classes': None,
#    'metadata': None,
#    'has_children': None,
#    'worker_version_id': None,
#    'worker_run': None,
#    'confidence': None}]}

# %%
for elem in elements["results"]:
  id = elem["id"]
  name = elem["name"]
  path = elem["zone"]["image"]["path"]
  lpath = path.split('%2F')
  commune = lpath[3]
  print(id,name,commune)
  cli.request('CreateMetaData',id=id,body={"type":"text","name":"commune","value":commune})
# Out:
# c8c9b171-906b-4ff9-8f43-dddc9905fc80 FRAD094_3P_000387_01_0002 MAROLLES
# a0002f6b-d91e-49aa-980f-789bf1c89ba3 FRAD094_3P_000387_01_0003 MAROLLES
# 6d0f0e46-0e24-477f-95a2-495f79f6faef FRAD094_3P_000387_01_0006 MAROLLES
# 51e0c722-c848-4dbb-8afe-327e49512258 FRAD094_3P_000387_01_0007 MAROLLES
# 6b7fc79d-6267-4a31-87d7-d70d692ed4bc FRAD094_3P_000387_01_0020 MAROLLES
# 44cac607-e546-4b34-ac31-c8b8b0995ddb FRAD094_3P_000387_01_0021 MAROLLES
# 3e550d9c-f019-499a-9b30-da55245943e5 FRAD094_3P_000387_01_0024 MAROLLES
# 48decc78-e30f-4452-9835-124b51576da1 FRAD094_3P_000387_01_0025 MAROLLES
# bae6d53f-2370-41f4-9e34-0a310a5298b7 FRAD094_3P_000387_01_0028 MAROLLES
# e29fa7ae-4c9c-4939-8641-a9dec141b26c FRAD094_3P_000387_01_0029 MAROLLES
# 3a902f11-c971-4377-ac79-65b8b9fae788 FRAD094_3P_000387_01_0032 MAROLLES
# 026cec76-f3e4-4ad6-b914-e6043f9c39f5 FRAD094_3P_000387_01_0041 MAROLLES
# 340e53ca-85d4-459b-a1f2-31938fc811c7 FRAD094_3P_000387_01_0042 MAROLLES
# c9346441-cf2f-4d0c-b88e-b858a883283b FRAD094_3P_000387_01_0045 MAROLLES
# 690d0a2e-7a2d-432d-9163-2eb96a1137c8 FRAD094_3P_000387_01_0046 MAROLLES
# 8ad0f719-fd08-4b41-9329-42a5dc1fa3b9 FRAD094_3P_000387_01_0049 MAROLLES
# 20311c8b-35ae-4696-80bf-995a261d64d2 FRAD094_3P_000387_01_0054 MAROLLES
# a563d0b8-0abb-4a1a-babf-890cab747321 FRAD094_3P_000387_01_0057 MAROLLES
# ee8296b0-f328-4be0-a7d6-d98a3ee2f77d FRAD094_3P_000387_01_0076 MAROLLES
# 2d56ef21-6f6d-4f8f-8af8-c2eebaf08b73 FRAD094_3P_000387_01_0079 MAROLLES
# 0ce77406-ae1c-4248-adc3-d4599ba702fb FRAD094_3P_000387_01_0080 MAROLLES
# 10d0200c-2d39-457b-9687-bd1ca6d38fb1 FRAD094_3P_000387_01_0083 MAROLLES
# bdf51b04-bcb8-469a-b8e2-03a380777f35 FRAD094_3P_000387_01_0088 MAROLLES
# 3fe40da1-daa7-42a9-b43b-cd1002827b8d FRAD094_3P_000387_01_0091 MAROLLES
# 2c7299da-97bb-4b08-9d81-8d714cdebc54 FRAD094_3P_000387_01_0092 MAROLLES
# 204e0289-e4ea-4acd-9fbb-162d3cd896d5 FRAD094_3P_000387_01_0095 MAROLLES
# 37491f3e-dc15-4467-922f-cf117dcbe15b FRAD094_3P_000387_01_0096 MAROLLES
# e483fe04-8259-44a7-9806-aca7a4e37508 FRAD094_3P_000387_01_0099 MAROLLES
# 2bce01a0-b075-4ca5-83cc-c61b256361d5 FRAD094_3P_000387_01_0100 MAROLLES

# %%
for elem in elements["results"]:
  id = elem["id"]
  name = elem["name"]
  path = elem["zone"]["image"]["path"]
  lpath = path.split('%2F')
  commune = lpath[3]
  print(id,name,commune)
  cli.request('CreateMetaData',id=id,body={"type":"text","name":"cote","value":name})
# Out:
# c8c9b171-906b-4ff9-8f43-dddc9905fc80 FRAD094_3P_000387_01_0002 MAROLLES
# a0002f6b-d91e-49aa-980f-789bf1c89ba3 FRAD094_3P_000387_01_0003 MAROLLES
# 6d0f0e46-0e24-477f-95a2-495f79f6faef FRAD094_3P_000387_01_0006 MAROLLES
# 51e0c722-c848-4dbb-8afe-327e49512258 FRAD094_3P_000387_01_0007 MAROLLES
# 6b7fc79d-6267-4a31-87d7-d70d692ed4bc FRAD094_3P_000387_01_0020 MAROLLES
# 44cac607-e546-4b34-ac31-c8b8b0995ddb FRAD094_3P_000387_01_0021 MAROLLES
# 3e550d9c-f019-499a-9b30-da55245943e5 FRAD094_3P_000387_01_0024 MAROLLES
# 48decc78-e30f-4452-9835-124b51576da1 FRAD094_3P_000387_01_0025 MAROLLES
# bae6d53f-2370-41f4-9e34-0a310a5298b7 FRAD094_3P_000387_01_0028 MAROLLES
# e29fa7ae-4c9c-4939-8641-a9dec141b26c FRAD094_3P_000387_01_0029 MAROLLES
# 3a902f11-c971-4377-ac79-65b8b9fae788 FRAD094_3P_000387_01_0032 MAROLLES
# 026cec76-f3e4-4ad6-b914-e6043f9c39f5 FRAD094_3P_000387_01_0041 MAROLLES
# 340e53ca-85d4-459b-a1f2-31938fc811c7 FRAD094_3P_000387_01_0042 MAROLLES
# c9346441-cf2f-4d0c-b88e-b858a883283b FRAD094_3P_000387_01_0045 MAROLLES
# 690d0a2e-7a2d-432d-9163-2eb96a1137c8 FRAD094_3P_000387_01_0046 MAROLLES
# 8ad0f719-fd08-4b41-9329-42a5dc1fa3b9 FRAD094_3P_000387_01_0049 MAROLLES
# 20311c8b-35ae-4696-80bf-995a261d64d2 FRAD094_3P_000387_01_0054 MAROLLES
# a563d0b8-0abb-4a1a-babf-890cab747321 FRAD094_3P_000387_01_0057 MAROLLES
# ee8296b0-f328-4be0-a7d6-d98a3ee2f77d FRAD094_3P_000387_01_0076 MAROLLES
# 2d56ef21-6f6d-4f8f-8af8-c2eebaf08b73 FRAD094_3P_000387_01_0079 MAROLLES
# 0ce77406-ae1c-4248-adc3-d4599ba702fb FRAD094_3P_000387_01_0080 MAROLLES
# 10d0200c-2d39-457b-9687-bd1ca6d38fb1 FRAD094_3P_000387_01_0083 MAROLLES
# bdf51b04-bcb8-469a-b8e2-03a380777f35 FRAD094_3P_000387_01_0088 MAROLLES
# 3fe40da1-daa7-42a9-b43b-cd1002827b8d FRAD094_3P_000387_01_0091 MAROLLES
# 2c7299da-97bb-4b08-9d81-8d714cdebc54 FRAD094_3P_000387_01_0092 MAROLLES
# 204e0289-e4ea-4acd-9fbb-162d3cd896d5 FRAD094_3P_000387_01_0095 MAROLLES
# 37491f3e-dc15-4467-922f-cf117dcbe15b FRAD094_3P_000387_01_0096 MAROLLES
# e483fe04-8259-44a7-9806-aca7a4e37508 FRAD094_3P_000387_01_0099 MAROLLES
# 2bce01a0-b075-4ca5-83cc-c61b256361d5 FRAD094_3P_000387_01_0100 MAROLLES
